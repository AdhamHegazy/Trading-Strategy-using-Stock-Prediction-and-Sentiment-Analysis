# %% [markdown]
# # Collecting Scraped Json Files in One CSV File

# %% [markdown]
# # Objective
#  This notebook is simply collecting all scraped json files in one DataFrame and saving it in one csv file

# %%
import os, json
import pandas as pd
import numpy as np
import glob
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Collecting Data From Json Files

# %%
l=[]

# %%
path_to_json = '/content/drive/MyDrive/Application on Sentiment Analysis submission/Dataset/Scraped Dataset/Scraped Files/Scraped' 

json_pattern = os.path.join(path_to_json,'*.json')
# print(json_pattern)
file_list = glob.glob(json_pattern)

l=l+file_list
print(len(l))
# Out:
# 363

# %%
path_to_json = '/content/drive/MyDrive/Application on Sentiment Analysis submission/Dataset/Scraped Dataset/Scraped Files/Scraped_2' 

json_pattern = os.path.join(path_to_json,'*.json')
# print(json_pattern)
file_list = glob.glob(json_pattern)

l=l+file_list
print(len(l))
# Out:
# 7761

# %%
path_to_json = '/content/drive/MyDrive/Application on Sentiment Analysis submission/Dataset/Scraped Dataset/Scraped Files/Scraped_3' 

json_pattern = os.path.join(path_to_json,'*.json')
# print(json_pattern)
file_list = glob.glob(json_pattern)

l=l+file_list
print(len(l))
# Out:
# 9050

# %%
df = pd.DataFrame()

# %%
for file in l:
    data = pd.read_json(file)
    df = df.append(data, ignore_index = True)
df
# Out:
#                id                                               text  \
# 0       453906792                                $FB coming tmw🚀🚀🚀🥱👽
# 1       453906759                            $FB what a pile of shit
# 2       453906671                        $FB user growth will shine?
# 3       453906661  $FB Wow.. someone stepped in with a massive bu...
# 4       453906652                   $FB Betting on a nice Meta beat.
# ...           ...                                                ...
# 271494  454182528  $AAPL if earnings crap the bed, it&#39;s gonna...
# 271495  454181757  $AAPL Buy for the long term. This is a no brai...
# 271496  454181517  $SPY if you’re not buying stocks today then yo...
# 271497  454181212  $TSLA  You know what I guess if you can move a...
# 271498  454180891  $AAPL 😂😂😂you brain dead’s amazing remember thi...
#
#                         time  \
# 0       2022-04-21T20:30:59Z
# 1       2022-04-21T20:30:55Z
# 2       2022-04-21T20:30:43Z
# ...

# %%
bearish = df[df['sentiment'] == 'Bearish'].index
df[df['sentiment'] == 'Bearish'].shape
# Out:
# (42038, 5)

# %%
Bullish = df[df['sentiment'] == 'Bullish'].index
df[df['sentiment'] == 'Bullish'].shape
# Out:
# (82492, 5)

# %%
from google.colab import files
df.to_csv('df.csv', encoding = 'utf-8-sig') 
files.download('df.csv')
